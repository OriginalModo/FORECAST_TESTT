# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import statsmodels.api as sm
from pandas.tseries.offsets import DateOffset
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf

# %%
df = pd.read_csv('data3.csv')

# %%
df.head()
# Out:
#       SALE_DT  Perrin Freres monthly champagne sales millions ?64-?72
# 0  2019-01-01                                             2815.0
# 1  2019-01-02                                             2672.0
# 2  2019-01-03                                             2755.0
# 3  2019-01-04                                             2721.0
# 4  2019-01-05                                             2946.0

# %%
df.columns = ['Month', 'Sales']
df.head()
# Out:
#         Month   Sales
# 0  2019-01-01  2815.0
# 1  2019-01-02  2672.0
# 2  2019-01-03  2755.0
# 3  2019-01-04  2721.0
# 4  2019-01-05  2946.0

# %%
df.shape
# Out:
# (107, 2)

# %%
df.isnull().sum()
# Out:
# Month    1
# Sales    2
# dtype: int64

# %%
df.tail()
# Out:
#                                                  Month   Sales
# 102                                         2019-04-13  4298.0
# 103                                         2019-04-14  1413.0
# 104                                         2019-04-15  5877.0
# 105                                                NaN     NaN
# 106  Perrin Freres monthly champagne sales millions...     NaN

# %%
df.drop(106, axis=0, inplace=True)

# %%
df.drop(105, axis=0, inplace=True)

# %%
df.shape
# Out:
# (105, 2)

# %%
df.dtypes
# Out:
# Month     object
# Sales    float64
# dtype: object

# %%
df['Month'] = pd.to_datetime(df['Month'])

# %%
df.dtypes
# Out:
# Month    datetime64[ns]
# Sales           float64
# dtype: object

# %%
df.head()
# Out:
#        Month   Sales
# 0 2019-01-01  2815.0
# 1 2019-01-02  2672.0
# 2 2019-01-03  2755.0
# 3 2019-01-04  2721.0
# 4 2019-01-05  2946.0

# %%
df.set_index('Month', inplace=True)

# %%
df.head()
# Out:
#              Sales
# Month
# 2019-01-01  2815.0
# 2019-01-02  2672.0
# 2019-01-03  2755.0
# 2019-01-04  2721.0
# 2019-01-05  2946.0

# %%
df.describe()
# Out:
#               Sales
# count    105.000000
# mean    4761.152381
# std     2553.502601
# min     1413.000000
# 25%     3113.000000
# 50%     4217.000000
# 75%     5221.000000
# max    13916.000000

# %%
df.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
adfuller(df['Sales'])
# Out:
# (-1.833593056327623,
#  0.363915771660245,
#  11,
#  93,
#  {'1%': -3.502704609582561,
#   '5%': -2.8931578098779522,
#   '10%': -2.583636712914788},
#  1478.4633060594724)

# %%
def adfuller_test(sales):
    result = adfuller(sales)
    
    labels = ['ADF test statistics', 'p-value', 'Lags used', 'Number of obs used']
    
    for value, label in zip(result, labels):
        print('{} : {} '.format(label, value))
        
    if result[1]<=0.05:
        print('Strong evidence against null hypothesis, reject the null hypothesis and data is stationary')
    else:
        print('Weak evidence against null hypothesis, accept the null hypothesis and data is not stationary')

# %%
adfuller_test(df['Sales'])
# Out:
# ADF test statistics : -1.833593056327623
# p-value : 0.363915771660245
# Lags used : 11
# Number of obs used : 93
# Weak evidence against null hypothesis, accept the null hypothesis and data is not stationary

# %%
df
# Out:
#              Sales
# Month
# 2019-01-01  2815.0
# 2019-01-02  2672.0
# 2019-01-03  2755.0
# 2019-01-04  2721.0
# 2019-01-05  2946.0
# ...            ...
# 2019-04-11  4618.0
# 2019-04-12  5312.0
# 2019-04-13  4298.0
# 2019-04-14  1413.0
# 2019-04-15  5877.0
#
# [105 rows x 1 columns]

# %%
df['Sales'].shift(1)
# Out:
# Month
# 2019-01-01       NaN
# 2019-01-02    2815.0
# 2019-01-03    2672.0
# 2019-01-04    2755.0
# 2019-01-05    2721.0
#                ...
# 2019-04-11    4788.0
# 2019-04-12    4618.0
# 2019-04-13    5312.0
# 2019-04-14    4298.0
# 2019-04-15    1413.0
# Name: Sales, Length: 105, dtype: float64

# %%
df['Sales first diff.'] = df['Sales'] - df['Sales'].shift(1)

# %%
df.head()
# Out:
#              Sales  Sales first diff.
# Month
# 2019-01-01  2815.0                NaN
# 2019-01-02  2672.0             -143.0
# 2019-01-03  2755.0               83.0
# 2019-01-04  2721.0              -34.0
# 2019-01-05  2946.0              225.0

# %%
df['Seasonal first diff.'] = df['Sales'] - df['Sales'].shift(12)

# %%
df.head()
# Out:
#              Sales  Sales first diff.  Seasonal first diff.
# Month
# 2019-01-01  2815.0                NaN                   NaN
# 2019-01-02  2672.0             -143.0                   NaN
# 2019-01-03  2755.0               83.0                   NaN
# 2019-01-04  2721.0              -34.0                   NaN
# 2019-01-05  2946.0              225.0                   NaN

# %%
adfuller_test(df['Seasonal first diff.'].dropna())
# Out:
# ADF test statistics : -7.626619157213164
# p-value : 2.060579696813685e-11
# Lags used : 0
# Number of obs used : 92
# Strong evidence against null hypothesis, reject the null hypothesis and data is stationary

# %%
df['Seasonal first diff.'].plot()
# Out:
# <Axes: xlabel='Month'>

# %%
df.head(15)
# Out:
#              Sales  Sales first diff.  Seasonal first diff.
# Month
# 2019-01-01  2815.0                NaN                   NaN
# 2019-01-02  2672.0             -143.0                   NaN
# 2019-01-03  2755.0               83.0                   NaN
# 2019-01-04  2721.0              -34.0                   NaN
# 2019-01-05  2946.0              225.0                   NaN
# 2019-01-06  3036.0               90.0                   NaN
# 2019-01-07  2282.0             -754.0                   NaN
# 2019-01-08  2212.0              -70.0                   NaN
# 2019-01-09  2922.0              710.0                   NaN
# 2019-01-10  4301.0             1379.0                   NaN
# 2019-01-11  5764.0             1463.0                   NaN
# 2019-01-12  7312.0             1548.0                   NaN
# 2019-01-13  2541.0            -4771.0                -274.0
# 2019-01-14  2475.0              -66.0                -197.0
# 2019-01-15  3031.0              556.0                 276.0

# %%
fig = plt.figure(figsize = (12,8))
ax1 = fig.add_subplot(211)
fig = plot_acf(df['Seasonal first diff.'].iloc[13:], lags=40, ax=ax1)

ax2 = fig.add_subplot(212)
fig = plot_pacf(df['Seasonal first diff.'].iloc[13:], lags=40, ax=ax2)

# %%
model = ARIMA(df['Sales'], order=(1,1,1))
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 model = ARIMA(df['Sales'], order=(1,1,1))
#
# File E:\All_Python_Frameworks\FORECAST_TEST\venv\lib\site-packages\statsmodels\tsa\arima_model.py:45, in ARIMA.__init__(self, *args, **kwargs)
#      44 def __init__(self, *args, **kwargs):
# ---> 45     super().__init__(*args, **kwargs)
#
# File E:\All_Python_Frameworks\FORECAST_TEST\venv\lib\site-packages\statsmodels\tsa\arima_model.py:29, in ARMA.__init__(self, *args, **kwargs)
#      28 def __init__(self, *args, **kwargs):
# ---> 29     raise NotImplementedError(ARIMA_DEPRECATION_ERROR)
#
# NotImplementedError:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been removed in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and statsmodels.tsa.SARIMAX.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained. It also offers alternative specialized
# parameter estimators.

# %%
model = model.fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 model = model.fit()
#
# NameError: name 'model' is not defined

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 model.summary()
#
# NameError: name 'model' is not defined

# %%
df.shape
# Out:
# (105, 3)

# %%
df['forecast'] = model.predict(start=90, end=103, dynamic=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df['forecast'] = model.predict(start=90, end=103, dynamic=True)
#
# NameError: name 'model' is not defined

# %%
df.tail(20)
# Out:
#               Sales  Sales first diff.  Seasonal first diff.
# Month
# 2019-03-27   3162.0             -772.0                 263.0
# 2019-03-28   4286.0             1124.0                 916.0
# 2019-03-29   4676.0              390.0                 936.0
# 2019-03-30   5010.0              334.0                2083.0
# 2019-03-31   4874.0             -136.0                 888.0
# 2019-04-01   4633.0             -241.0                 416.0
# 2019-04-02   1659.0            -2974.0                 -79.0
# 2019-04-03   5951.0             4292.0                 730.0
# 2019-04-04   6981.0             1030.0                 557.0
# 2019-04-05   9851.0             2870.0                   9.0
# 2019-04-06  12670.0             2819.0                -406.0
# 2019-04-07   4348.0            -8322.0                 414.0
# 2019-04-08   3564.0             -784.0                 402.0
# 2019-04-09   4577.0             1013.0                 291.0
# 2019-04-10   4788.0              211.0                 112.0
# 2019-04-11   4618.0             -170.0                -392.0
# 2019-04-12   5312.0              694.0                 438.0
# 2019-04-13   4298.0            -1014.0                -335.0
# 2019-04-14   1413.0            -2885.0                -246.0
# 2019-04-15   5877.0             4464.0                 -74.0

# %%
df[['Sales', 'forecast']].plot(figsize=(12,8))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df[['Sales', 'forecast']].plot(figsize=(12,8))
#
# File E:\All_Python_Frameworks\FORECAST_TEST\venv\lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File E:\All_Python_Frameworks\FORECAST_TEST\venv\lib\site-packages\pandas\core\indexes\base.py:5876, in Index._get_indexer_strict(self, key, axis_name)
#    5873 else:
#    5874     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5876 self._raise_if_missing(keyarr, indexer, axis_name)
#    5878 keyarr = self.take(indexer)
#    5879 if isinstance(key, Index):
#    5880     # GH 42790 - Preserve name from an Index
#
# File E:\All_Python_Frameworks\FORECAST_TEST\venv\lib\site-packages\pandas\core\indexes\base.py:5938, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5935     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5937 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5938 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['forecast'] not in index"

# %%
model = sm.tsa.statespace.SARIMAX(df['Sales'], order=(1,1,1), seasonal_order=(1,1,1,12))
# Out:
# E:\All_Python_Frameworks\FORECAST_TEST\venv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\All_Python_Frameworks\FORECAST_TEST\venv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
results = model.fit()

# %%
df['forecast_SARIMAX'] = results.predict(start=90, end=103, dynamic=True)

# %%
df.tail(20)
# Out:
#               Sales  Sales first diff.  Seasonal first diff.  forecast_SARIMAX
# Month
# 2019-03-27   3162.0             -772.0                 263.0               NaN
# 2019-03-28   4286.0             1124.0                 916.0               NaN
# 2019-03-29   4676.0              390.0                 936.0               NaN
# 2019-03-30   5010.0              334.0                2083.0               NaN
# 2019-03-31   4874.0             -136.0                 888.0               NaN
# 2019-04-01   4633.0             -241.0                 416.0       4437.324143
# 2019-04-02   1659.0            -2974.0                 -79.0       2050.747444
# 2019-04-03   5951.0             4292.0                 730.0       5493.376381
# 2019-04-04   6981.0             1030.0                 557.0       6752.039127
# 2019-04-05   9851.0             2870.0                   9.0      10327.297758
# 2019-04-06  12670.0             2819.0                -406.0      13632.324040
# 2019-04-07   4348.0            -8322.0                 414.0       3832.960772
# 2019-04-08   3564.0             -784.0                 402.0       3313.096797
# 2019-04-09   4577.0             1013.0                 291.0       4285.475571
# 2019-04-10   4788.0              211.0                 112.0       4701.092052
# 2019-04-11   4618.0             -170.0                -392.0       4717.509848
# 2019-04-12   5312.0              694.0                 438.0       4906.403459
# 2019-04-13   4298.0            -1014.0                -335.0       4685.435562
# 2019-04-14   1413.0            -2885.0                -246.0       2232.408084
# 2019-04-15   5877.0             4464.0                 -74.0               NaN

# %%
df[['Sales','forecast_SARIMAX']].plot(figsize=(12,10))
# Out:
# <Axes: xlabel='Month'>

# %%
future_dates = [df.index[-1] + DateOffset(months=x)for x in range(0,12)]

# %%
future_dates[1:]
# Out:
# [Timestamp('2019-05-15 00:00:00'),
#  Timestamp('2019-06-15 00:00:00'),
#  Timestamp('2019-07-15 00:00:00'),
#  Timestamp('2019-08-15 00:00:00'),
#  Timestamp('2019-09-15 00:00:00'),
#  Timestamp('2019-10-15 00:00:00'),
#  Timestamp('2019-11-15 00:00:00'),
#  Timestamp('2019-12-15 00:00:00'),
#  Timestamp('2020-01-15 00:00:00'),
#  Timestamp('2020-02-15 00:00:00'),
#  Timestamp('2020-03-15 00:00:00')]

# %%
future_dataset = pd.DataFrame(index = future_dates[1:], columns = df.columns)

# %%
future_dataset.tail()
# Out:
#            Sales Sales first diff. Seasonal first diff. forecast_SARIMAX
# 2019-11-15   NaN               NaN                  NaN              NaN
# 2019-12-15   NaN               NaN                  NaN              NaN
# 2020-01-15   NaN               NaN                  NaN              NaN
# 2020-02-15   NaN               NaN                  NaN              NaN
# 2020-03-15   NaN               NaN                  NaN              NaN

# %%
future_df = pd.concat([df, future_dataset])

# %%
future_df.shape
# Out:
# (116, 4)

# %%
future_df['forecast_SARIMAX2'] = results.predict(start=90, end=124, dynamic=True)

# %%
future_df[['Sales', 'forecast_SARIMAX2']].plot(figsize=(12,8))
# Out:
# <Axes: >
