# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import statsmodels.api as sm
from pandas.tseries.offsets import DateOffset
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
from datetime import datetime

# %%
df = pd.read_csv('SUM_DATA.csv')
# df = pd.read_csv('data.csv')

# %%
df = df.drop('STORE', axis=1)

# %%
df.head()
# Out:
#    SALE_DT         SALES
# 0  2019-01  6.116698e+08
# 1  2019-02  6.254852e+08
# 2  2019-03  7.278651e+08
# 3  2019-04  6.499091e+08
# 4  2019-05  6.118044e+08

# %%
df.columns = ['Month', 'Sales']
df.head()
# Out:
#      Month         Sales
# 0  2019-01  6.116698e+08
# 1  2019-02  6.254852e+08
# 2  2019-03  7.278651e+08
# 3  2019-04  6.499091e+08
# 4  2019-05  6.118044e+08

# %%
df.shape
# Out:
# (42, 2)

# %%
df.isnull().sum()
# Out:
# Month    0
# Sales    0
# dtype: int64

# %%
df.tail()
# Out:
#       Month         Sales
# 37  2022-02  5.327292e+08
# 38  2022-03  7.537410e+08
# 39  2022-04  6.054326e+08
# 40  2022-05  5.480671e+08
# 41  2022-06  5.027106e+08

# %%
df.shape
# Out:
# (42, 2)

# %%
df.dtypes
# Out:
# Month     object
# Sales    float64
# dtype: object

# %%
df['Month'] = pd.to_datetime(df['Month'])

# %%
df.dtypes
# Out:
# Month    datetime64[ns]
# Sales           float64
# dtype: object

# %%
df.head()
# Out:
#        Month         Sales
# 0 2019-01-01  6.116698e+08
# 1 2019-02-01  6.254852e+08
# 2 2019-03-01  7.278651e+08
# 3 2019-04-01  6.499091e+08
# 4 2019-05-01  6.118044e+08

# %%
df.set_index('Month', inplace=True)

# %%
df.head()
# Out:
#                    Sales
# Month
# 2019-01-01  6.116698e+08
# 2019-02-01  6.254852e+08
# 2019-03-01  7.278651e+08
# 2019-04-01  6.499091e+08
# 2019-05-01  6.118044e+08

# %%
df.describe()
# Out:
#               Sales
# count  4.200000e+01
# mean   5.574131e+08
# std    1.139248e+08
# min    3.519605e+08
# 25%    4.789646e+08
# 50%    5.457878e+08
# 75%    6.101105e+08
# max    8.893998e+08

# %%
df.plot(figsize=(14,8))
# Out:
# <Axes: xlabel='Month'>

# %%
adfuller(df['Sales'])
# Out:
# (-4.821488413501406,
#  4.946542437323099e-05,
#  0,
#  41,
#  {'1%': -3.60098336718852,
#   '5%': -2.9351348158036012,
#   '10%': -2.6059629803688282},
#  1245.739920785457)

# %%
def adfuller_test(sales):
    result = adfuller(sales)
    
    labels = ['Статистика теста ADF', 'P-значение', 'Используемые лаги', 'Критерий ADF']
    
    for value, label in zip(result, labels):
        print(f'{label}, {value}')

    if result[1]<=0.05:
        print('Данные стационарны')
    else:
        print('Данные не стационарны')

# %%
adfuller_test(df['Sales'])
# Out:
# Статистика теста ADF, -4.821488413501406
# P-значение, 4.946542437323099e-05
# Используемые лаги, 0
# Критерий ADF, 41
# Данные стационарны

# %%
df
# Out:
#                    Sales
# Month
# 2019-01-01  6.116698e+08
# 2019-02-01  6.254852e+08
# 2019-03-01  7.278651e+08
# 2019-04-01  6.499091e+08
# 2019-05-01  6.118044e+08
# 2019-06-01  5.750736e+08
# 2019-07-01  5.511557e+08
# 2019-08-01  5.745834e+08
# 2019-09-01  5.596533e+08
# 2019-10-01  5.735714e+08
# 2019-11-01  6.270833e+08
# 2019-12-01  8.893998e+08
# 2020-01-01  5.332384e+08
# 2020-02-01  5.864687e+08
# 2020-03-01  6.548460e+08
# 2020-04-01  3.519605e+08
# 2020-05-01  4.011334e+08
# 2020-06-01  4.305238e+08
# 2020-07-01  4.413847e+08
# 2020-08-01  4.530366e+08
# 2020-09-01  4.678771e+08
# 2020-10-01  4.617411e+08
# 2020-11-01  4.920891e+08
# 2020-12-01  7.550166e+08
# 2021-01-01  4.653435e+08
# 2021-02-01  4.877776e+08
# 2021-03-01  5.521452e+08
# 2021-04-01  5.271996e+08
# 2021-05-01  5.048700e+08
# 2021-06-01  4.471601e+08
# 2021-07-01  4.459584e+08
# 2021-08-01  4.760269e+08
# 2021-09-01  5.060857e+08
# 2021-10-01  5.435085e+08
# 2021-11-01  5.500617e+08
# 2021-12-01  8.579605e+08
# 2022-01-01  4.980023e+08
# 2022-02-01  5.327292e+08
# 2022-03-01  7.537410e+08
# 2022-04-01  6.054326e+08
# 2022-05-01  5.480671e+08
# 2022-06-01  5.027106e+08

# %%
df['Sales'].shift(1)
# Out:
# Month
# 2019-01-01             NaN
# 2019-02-01    6.116698e+08
# 2019-03-01    6.254852e+08
# 2019-04-01    7.278651e+08
# 2019-05-01    6.499091e+08
# 2019-06-01    6.118044e+08
# 2019-07-01    5.750736e+08
# 2019-08-01    5.511557e+08
# 2019-09-01    5.745834e+08
# 2019-10-01    5.596533e+08
# 2019-11-01    5.735714e+08
# 2019-12-01    6.270833e+08
# 2020-01-01    8.893998e+08
# 2020-02-01    5.332384e+08
# 2020-03-01    5.864687e+08
# 2020-04-01    6.548460e+08
# 2020-05-01    3.519605e+08
# 2020-06-01    4.011334e+08
# 2020-07-01    4.305238e+08
# 2020-08-01    4.413847e+08
# 2020-09-01    4.530366e+08
# 2020-10-01    4.678771e+08
# 2020-11-01    4.617411e+08
# 2020-12-01    4.920891e+08
# 2021-01-01    7.550166e+08
# 2021-02-01    4.653435e+08
# 2021-03-01    4.877776e+08
# 2021-04-01    5.521452e+08
# 2021-05-01    5.271996e+08
# 2021-06-01    5.048700e+08
# 2021-07-01    4.471601e+08
# 2021-08-01    4.459584e+08
# 2021-09-01    4.760269e+08
# 2021-10-01    5.060857e+08
# 2021-11-01    5.435085e+08
# 2021-12-01    5.500617e+08
# 2022-01-01    8.579605e+08
# 2022-02-01    4.980023e+08
# 2022-03-01    5.327292e+08
# 2022-04-01    7.537410e+08
# 2022-05-01    6.054326e+08
# 2022-06-01    5.480671e+08
# Name: Sales, dtype: float64

# %%
df['Sales first diff.'] = df['Sales'] - df['Sales'].shift(1)

# %%
df.head()
# Out:
#                    Sales  Sales first diff.
# Month
# 2019-01-01  6.116698e+08                NaN
# 2019-02-01  6.254852e+08       1.381540e+07
# 2019-03-01  7.278651e+08       1.023798e+08
# 2019-04-01  6.499091e+08      -7.795598e+07
# 2019-05-01  6.118044e+08      -3.810472e+07

# %%
df['Seasonal first diff.'] = df['Sales'] - df['Sales'].shift(12)

# %%
df.head()
# Out:
#                    Sales  Sales first diff.  Seasonal first diff.
# Month
# 2019-01-01  6.116698e+08                NaN                   NaN
# 2019-02-01  6.254852e+08       1.381540e+07                   NaN
# 2019-03-01  7.278651e+08       1.023798e+08                   NaN
# 2019-04-01  6.499091e+08      -7.795598e+07                   NaN
# 2019-05-01  6.118044e+08      -3.810472e+07                   NaN

# %%
adfuller_test(df['Seasonal first diff.'].dropna())
# Out:
# Статистика теста ADF, -2.097711671011186
# P-значение, 0.24543574514074784
# Используемые лаги, 0
# Критерий ADF, 29
# Данные не стационарны

# %% [markdown]
# ## Seasonal first diff

# %%
# df['Seasonal first diff.'].plot()
df[['Seasonal first diff.']].plot(figsize=(12,8))
# plt.ylabel('Seasonal first diff')
# Out:
# <Axes: xlabel='Month'>

# %%
df.head(15)
# Out:
#                    Sales  Sales first diff.  Seasonal first diff.
# Month
# 2019-01-01  6.116698e+08                NaN                   NaN
# 2019-02-01  6.254852e+08       1.381540e+07                   NaN
# 2019-03-01  7.278651e+08       1.023798e+08                   NaN
# 2019-04-01  6.499091e+08      -7.795598e+07                   NaN
# 2019-05-01  6.118044e+08      -3.810472e+07                   NaN
# 2019-06-01  5.750736e+08      -3.673080e+07                   NaN
# 2019-07-01  5.511557e+08      -2.391781e+07                   NaN
# 2019-08-01  5.745834e+08       2.342769e+07                   NaN
# 2019-09-01  5.596533e+08      -1.493012e+07                   NaN
# 2019-10-01  5.735714e+08       1.391809e+07                   NaN
# 2019-11-01  6.270833e+08       5.351190e+07                   NaN
# 2019-12-01  8.893998e+08       2.623165e+08                   NaN
# 2020-01-01  5.332384e+08      -3.561614e+08          -78431410.94
# 2020-02-01  5.864687e+08       5.323035e+07          -39016463.49
# 2020-03-01  6.548460e+08       6.837730e+07          -73019010.18

# %%
fig = plt.figure(figsize = (12,8))
ax1 = fig.add_subplot(211)
fig = plot_acf(df['Seasonal first diff.'].iloc[13:], lags=10, ax=ax1)

ax2 = fig.add_subplot(212)
fig = plot_pacf(df['Seasonal first diff.'].iloc[13:], lags=4, ax=ax2)

# %%
model = ARIMA(df['Sales'], order=(1,1,1))

# %%
model = model.fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Sales   No. Observations:                   42
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -821.762
# Date:                Sat, 29 Apr 2023   AIC                           1649.524
# Time:                        14:35:49   BIC                           1654.665
# Sample:                    01-01-2019   HQIC                          1651.396
#                          - 06-01-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3951      0.158      2.493      0.013       0.084       0.706
# ma.L1         -0.9891      0.209     -4.733      0.000      -1.399      -0.580
# sigma2      1.563e+16   9.49e-18   1.65e+33      0.000    1.56e+16    1.56e+16
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.30   Jarque-Bera (JB):                 4.27
# Prob(Q):                              0.58   Prob(JB):                         0.12
# Heteroskedasticity (H):               0.82   Skew:                             0.66
# Prob(H) (two-sided):                  0.72   Kurtosis:                         3.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.4e+48. Standard errors may be unstable.
# """

# %%
df.shape
# Out:
# (42, 3)

# %%
# df['forecast'] = model.predict(start=35, end=42, dynamic=True)

# %%
# df.tail(20)

# %%
# df[['Sales', 'forecast']].plot(figsize=(12,8))

# %% [markdown]
# ## Построение модели SARIMA

# %%
model = sm.tsa.statespace.SARIMAX(df['Sales'], order=(1,1,1), seasonal_order=(1,1,1,12))

# %%
results = model.fit()

# %%
df['forecast_SARIMAX'] = results.predict(start=20, end=42, dynamic=True)

# %%
df.tail(20)
# Out:
#                    Sales  Sales first diff.  Seasonal first diff.
# Month
# 2020-11-01  4.920891e+08       3.034795e+07         -1.349943e+08  \
# 2020-12-01  7.550166e+08       2.629275e+08         -1.343832e+08
# 2021-01-01  4.653435e+08      -2.896731e+08         -6.789488e+07
# 2021-02-01  4.877776e+08       2.243407e+07         -9.869116e+07
# 2021-03-01  5.521452e+08       6.436765e+07         -1.027008e+08
# 2021-04-01  5.271996e+08      -2.494566e+07          1.752391e+08
# 2021-05-01  5.048700e+08      -2.232959e+07          1.037366e+08
# 2021-06-01  4.471601e+08      -5.770991e+07          1.663631e+07
# 2021-07-01  4.459584e+08      -1.201634e+06          4.573786e+06
# 2021-08-01  4.760269e+08       3.006845e+07          2.299031e+07
# 2021-09-01  5.060857e+08       3.005884e+07          3.820859e+07
# 2021-10-01  5.435085e+08       3.742273e+07          8.176737e+07
# 2021-11-01  5.500617e+08       6.553182e+06          5.797259e+07
# 2021-12-01  8.579605e+08       3.078989e+08          1.029439e+08
# 2022-01-01  4.980023e+08      -3.599582e+08          3.265879e+07
# 2022-02-01  5.327292e+08       3.472694e+07          4.495166e+07
# 2022-03-01  7.537410e+08       2.210118e+08          2.015958e+08
# 2022-04-01  6.054326e+08      -1.483084e+08          7.823304e+07
# 2022-05-01  5.480671e+08      -5.736554e+07          4.319709e+07
# 2022-06-01  5.027106e+08      -4.535648e+07          5.555052e+07
#
#             forecast_SARIMAX
# Month
# 2020-11-01      4.981696e+08
# 2020-12-01      7.224427e+08
# 2021-01-01      5.092177e+08
# 2021-02-01      5.569276e+08
# 2021-03-01      6.309547e+08
# 2021-04-01      3.595793e+08
# 2021-05-01      3.959949e+08
# 2021-06-01      4.156593e+08
# 2021-07-01      4.213687e+08
# 2021-08-01      4.348839e+08
# 2021-09-01      4.218465e+08
# 2021-10-01      4.341657e+08
# 2021-11-01      4.814775e+08
# 2021-12-01      7.132353e+08
# 2022-01-01      4.718890e+08
# 2022-02-01      5.206850e+08
# 2022-03-01      5.936006e+08
# 2022-04-01      3.160259e+08
# 2022-05-01      3.549513e+08
# 2022-06-01      3.765292e+08

# %%
df[['Sales','forecast_SARIMAX']].plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# ## На графике видим, что модель SARIMAX показывает довольно точный прогноз, но видны расхождения

# %% [markdown]
# ## Строим прогноз на будущие периоды

# %%
future_dates = [df.index[-1] + DateOffset(months=x)for x in range(0,3)]

# %%
future_dates[1:]
# Out:
# [Timestamp('2022-07-01 00:00:00'), Timestamp('2022-08-01 00:00:00')]

# %%
future_dataset = pd.DataFrame(index = future_dates[1:], columns = df.columns)

# %%
future_dataset.tail()
# Out:
#            Sales Sales first diff. Seasonal first diff. forecast_SARIMAX
# 2022-07-01   NaN               NaN                  NaN              NaN
# 2022-08-01   NaN               NaN                  NaN              NaN

# %%
future_df = pd.concat([df, future_dataset])

# %%
future_df.shape
# Out:
# (44, 4)

# %%
future_df['forecast_SARIMAX2'] = results.predict(start=41, end=44, dynamic=True)

# %%
future_df[['Sales', 'forecast_SARIMAX2']].plot(figsize=(12,8))
# Out:
# <Axes: >

# %% [markdown]
# ## Построение прогноза на 07 и 08 месяцы 2022г.

# %%
future_dates = [df.index[-1] + DateOffset(months=x) for x in range(0, 24)]
future_dates[1:]
future_dataset = pd.DataFrame(index=future_dates[1:], columns=df.columns)
future_dataset.tail()
future_df = pd.concat([df, future_dataset])
future_df.shape
future_df['forecast_SARIMAX3'] = results.predict(start=41, end=65, dynamic=True)
future_df[['Sales', 'forecast_SARIMAX3']].plot(figsize=(12, 8))
# Out:
# <Axes: >

# %% [markdown]
# ## Бонус! Построение прогноза на последующие 2 года! =)

# %% [markdown]
# ## Итог для построения прогноза была выбрана модель SARIMAX. Её преимущество перед ARIMA состоит  в том, что она учитывает данные с внешними факторами (сезонность, праздники и тд.)
